# %% [markdown]
# # Dia 1 - Importação de dados
# ##7DaysOfCode - Python Pandas 1/7: Importação de dados

# %%
import pandas as pd

# %% [markdown]
# ### Importando o DataSet
# importando os dados de emprestimos dos ultimos 10 anos

# %%
dados_2010_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv?raw=true')
dados_2010_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv?raw=true')
dados_2011_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv?raw=true')
dados_2011_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv?raw=true')
dados_2012_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv?raw=true')
dados_2012_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv?raw=true')
dados_2013_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv?raw=true')
dados_2013_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv?raw=true')
dados_2014_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv?raw=true')
dados_2014_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv?raw=true')
dados_2015_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv?raw=true')
dados_2015_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv?raw=true')
dados_2016_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv?raw=true')
dados_2016_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv?raw=true')
dados_2017_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv?raw=true')
dados_2017_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv?raw=true')
dados_2018_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv?raw=true')
dados_2018_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv?raw=true')
dados_2019_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv?raw=true')
dados_2019_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv?raw=true')
dados_2020_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv?raw=true')

# %% [markdown]
# ### importando os dados dos exemplares

# %%
dados_exemplares = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')
dados_exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %% [markdown]
# ### Concatenando os dataframes de emprestimos

# %%
emprestimos_biblioteca = pd.concat([dados_2010_1,dados_2010_2,dados_2011_1,dados_2011_2,dados_2012_1,dados_2012_2,dados_2013_1,dados_2013_2,dados_2014_1,
                                    dados_2014_2,dados_2015_1,dados_2015_2,dados_2016_1,dados_2016_2,dados_2017_1,dados_2017_2,dados_2018_1,dados_2018_2,
                                    dados_2019_1,dados_2019_2,dados_2020_1],ignore_index=True)
emprestimos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos_biblioteca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2258018 entries, 0 to 2258017
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 120.6+ MB

# %%
emprestimos_biblioteca.describe()
# Out:
#        id_emprestimo  matricula_ou_siape
# count   2.258018e+06        2.254848e+06
# mean    2.617069e+06        6.127611e+09
# std     2.517077e+06        7.827175e+09
# min     7.096840e+05        0.000000e+00
# 25%     1.288985e+06        2.010057e+09
# 50%     1.854210e+06        2.012975e+09
# 75%     2.653337e+06        2.016069e+09
# max     1.032233e+07        2.022301e+10

# %% [markdown]
# ### verificar duplicidade dos dados

# %%
duplicado = emprestimos_biblioteca.duplicated()
duplicado
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4           True
#            ...
# 2258013    False
# 2258014    False
# 2258015    False
# 2258016    False
# 2258017    False
# Length: 2258018, dtype: bool

# %% [markdown]
# ### remover os dados duplicados

# %%
emprestimos_biblioteca = emprestimos_biblioteca.drop_duplicates()
emprestimos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 8               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
duplicado = emprestimos_biblioteca.duplicated()
duplicado
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 8          False
#            ...
# 2258013    False
# 2258014    False
# 2258015    False
# 2258016    False
# 2258017    False
# Length: 2257981, dtype: bool

# %% [markdown]
# ## verificar duplicidade do DataFrame de exemplares

# %%
duplicado = dados_exemplares.duplicated()
duplicado
# Out:
# index
# 0         False
# 1         False
# 2         False
# 3         False
# 5         False
#           ...
# 568580    False
# 568581    False
# 568582    False
# 568583    False
# 568584    False
# Length: 546237, dtype: bool

# %% [markdown]
# ### Unindo os DataFrames
# unir os dataFrames de emprestimo e exemplares

# %%
dados_biblioteca_completos = emprestimos_biblioteca.merge(dados_exemplares)
dados_biblioteca_completos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
dados_biblioteca_completos.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'registro_sistema'],
#       dtype='object')

# %% [markdown]
# Verificar nulos

# %%
dados_biblioteca_completos.isnull().sum()
# Out:
# id_emprestimo                 0
# codigo_barras                 0
# data_renovacao          1162077
# data_emprestimo               0
# data_devolucao             6178
# matricula_ou_siape         2893
# tipo_vinculo_usuario          0
# id_exemplar                   0
# colecao                       0
# biblioteca                    0
# status_material               0
# localizacao                   0
# registro_sistema              0
# dtype: int64

# %%
# verificar os valores unicos na coluna matricula_ou_siape
#dados.groupby('GENERO', dropna=False)['ID'].nunique()
dados_biblioteca_completos.groupby('matricula_ou_siape', dropna=False)['id_emprestimo'].nunique()
# Out:
# matricula_ou_siape
# 0.000000e+00       4
# 2.560000e+02      15
# 3.770000e+02      20
# 3.790000e+02       7
# 3.820000e+02       2
#                 ...
# 2.022101e+10      20
# 2.022101e+10      11
# 2.022300e+10      18
# 2.022301e+10       7
# NaN             2892
# Name: id_emprestimo, Length: 100560, dtype: int64

# %%
# filtrar os dados para verificar se matricula_ou_siape que não esta preenchida agrupando com tipo_vinculo_usuario

dados_biblioteca_completos[dados_biblioteca_completos['matricula_ou_siape'].isnull()].groupby('tipo_vinculo_usuario', dropna=False)['id_emprestimo'].nunique()
# Out:
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  100
# ALUNO DE PÓS-GRADUAÇÃO               88
# DOCENTE                              45
# DOCENTE EXTERNO                       7
# OUTROS                                5
# SERVIDOR TÉCNICO-ADMINISTRATIVO     187
# USUÁRIO EXTERNO                    2460
# Name: id_emprestimo, dtype: int64

# %% [markdown]
# A maior parte dos dados da matriculo que esta sem preencher é de usuarios Externos
# no momento não precisa ser tratados

# %% [markdown]
# Questões de diferentes perspectivas podem surgir como:
#
# - A quantidade de empréstimos está aumentando ou diminuindo ao decorrer dos últimos anos?
# - Em quais bibliotecas do sistema estão a maior quantidade de empréstimos?
# - Quais são os temas mais emprestados? E os menos?

# %% [markdown]
# # Dia 2 - Limpeza de dados
#
# ##7DaysOfCode - Python Pandas 2/7: 👩🏽‍💻 Limpeza de dados

# %%
# Quantidade de emprestimos

# %%
dados_biblioteca_completos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072522 entries, 0 to 2072521
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        object
#  3   data_emprestimo       object
#  4   data_devolucao        object
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
#  7   id_exemplar           int64
#  8   colecao               object
#  9   biblioteca            object
#  10  status_material       object
#  11  localizacao           int64
#  12  registro_sistema      int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 205.6+ MB

# %%
# converter a coluna 'data_emprestimo' para datetime
dados_biblioteca_completos['data_emprestimo'] = pd.to_datetime(dados_biblioteca_completos['data_emprestimo'])

# %%
# agrupar os dados de emprestimo data de emprestimo
dados_biblioteca_completos.groupby('data_emprestimo', dropna=False)['id_emprestimo'].nunique()
# Out:
# data_emprestimo
# 2010-01-04 07:44:10.721    1
# 2010-01-04 07:44:10.750    1
# 2010-01-04 08:08:44.081    1
# 2010-01-04 08:24:21.284    1
# 2010-01-04 08:27:33.569    1
#                           ..
# 2020-05-05 19:51:06.059    1
# 2020-05-05 19:51:06.135    1
# 2020-05-05 19:51:06.164    1
# 2020-06-09 11:54:02.669    1
# 2020-06-09 11:54:02.852    1
# Name: id_emprestimo, Length: 2068691, dtype: int64

# %%
#Extrair o ano da coluna 'data_emprestimo'
dados_biblioteca_completos['ano_emprestimo'] = dados_biblioteca_completos['data_emprestimo'].dt.year

# %%
print(dados_biblioteca_completos[['data_emprestimo', 'ano_emprestimo']])
# Out:
#                 data_emprestimo  ano_emprestimo
# 0       2010-01-04 07:44:10.721            2010
# 1       2010-03-01 12:40:56.212            2010
# 2       2010-01-04 07:44:10.750            2010
# 3       2010-02-11 11:16:30.335            2010
# 4       2010-03-04 13:36:26.599            2010
# ...                         ...             ...
# 2072517 2020-03-17 19:49:10.187            2020
# 2072518 2020-03-17 19:51:15.700            2020
# 2072519 2020-03-17 20:00:11.416            2020
# 2072520 2020-03-17 20:47:18.741            2020
# 2072521 2020-03-17 21:22:22.138            2020
#
# [2072522 rows x 2 columns]

# %%
# Extrair o mes da coluna 'data_emprestimo'
dados_biblioteca_completos['mes_emprestimo'] = dados_biblioteca_completos['data_emprestimo'].dt.month

# %%
# Exibir o dataFrame com as novas colunas de mes e ano
print(dados_biblioteca_completos[['data_emprestimo', 'ano_emprestimo', 'mes_emprestimo']])
# Out:
#                 data_emprestimo  ano_emprestimo  mes_emprestimo
# 0       2010-01-04 07:44:10.721            2010               1
# 1       2010-03-01 12:40:56.212            2010               3
# 2       2010-01-04 07:44:10.750            2010               1
# 3       2010-02-11 11:16:30.335            2010               2
# 4       2010-03-04 13:36:26.599            2010               3
# ...                         ...             ...             ...
# 2072517 2020-03-17 19:49:10.187            2020               3
# 2072518 2020-03-17 19:51:15.700            2020               3
# 2072519 2020-03-17 20:00:11.416            2020               3
# 2072520 2020-03-17 20:47:18.741            2020               3
# 2072521 2020-03-17 21:22:22.138            2020               3
#
# [2072522 rows x 3 columns]

# %%
dados_biblioteca_completos.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'registro_sistema', 'ano_emprestimo', 'mes_emprestimo'],
#       dtype='object')

# %%
dados_biblioteca_completos.head(5)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#           data_emprestimo                 data_devolucao  matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721  2010/01/05 16:26:12.662000000        2.008023e+09
# 1 2010-03-01 12:40:56.212  2010/04/30 14:42:35.366000000        2.009122e+09
# 2 2010-01-04 07:44:10.750  2010/01/12 07:34:13.934000000        2.008023e+09
# 3 2010-02-11 11:16:30.335  2010/03/04 08:54:32.262000000        2.008050e+09
# 4 2010-03-04 13:36:26.599  2010/03/31 18:04:29.669000000        2.007226e+08
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# Você deve ter visto que tem uma coluna identificada como “localização” e diversos números nela, mas você sabe o que significam estes números?
#
#
# "Os itens do acervo em uma biblioteca são organizados por um sistema de classificação de acordo com o respectivo tema. Existem diversos sistemas, mas este conjunto está de acordo com a CDU - Classificação Decimal Universal. Esta classificação é decimal, pois varia de acordo com a classe de cada assunto:
#
#
# - 000 a 099: Generalidades. Ciência e conhecimento.
# - 100 a 199: Filosofia e psicologia.
# - 200 a 299: Religião.
# - 300 a 399: Ciências sociais.
# - 400 a 499: Classe vaga. Provisoriamente não ocupada.
# - 500 a 599: Matemática e ciências naturais.
# - 600 a 699: Ciências aplicadas.
# - 700 a 799: Belas artes.
# - 800 a 899: Linguagem. Língua. Linguística.
# - 900 a 999: Geografia. Biografia. História."

# %%
# atribuir a coluna com nomenclatura da CDU
def atribuir_nome_cdu(cdu):
  if 000 <= cdu < 100:
    return 'Generalidades. Ciência e conhecimento.'
  elif 100 <= cdu < 200:
    return 'Filosofia e psicologia.'
  elif 200 <= cdu < 300:
    return 'Religião'
  elif 300 <= cdu < 400:
    return 'Ciências sociais'
  elif 400 <= cdu < 500:
    return 'Classe vaga. Provisoriamente não ocupada.'
  elif 500 <= cdu < 600:
    return 'Matemática e ciências naturais.'
  elif 600 <= cdu < 700:
    return 'Ciências aplicadas.'
  elif 700 <= cdu < 800:
    return 'Belas artes.'
  elif 800 <= cdu < 900:
    return 'Linguagem. Língua. Linguística.'
  elif 900 <= cdu < 1000:
    return 'Geografia. Biografia. História.'

# %%
# criar uma nova coluna cdu
#dados['GERACAO'] = dados['IDADE'].apply(determinar_geracao)
dados_biblioteca_completos['nome_cdu'] = dados_biblioteca_completos['localizacao'].apply(atribuir_nome_cdu)

# %%
dados_biblioteca_completos['nome_cdu'].value_counts()
# Out:
# nome_cdu
# Ciências aplicadas.                       1425473
# Ciências sociais                           369536
# Matemática e ciências naturais.             68744
# Generalidades. Ciência e conhecimento.      62521
# Religião                                    62295
# Filosofia e psicologia.                     60563
# Geografia. Biografia. História.              7989
# Belas artes.                                 7911
# Linguagem. Língua. Linguística.              7490
# Name: count, dtype: int64

# %% [markdown]
# Você precisará ainda excluir alguns dados e modificar outros.
#
# A coluna "registro_sistema", por exemplo, não está fazendo sentido para essa análise, por isso você pode exclui-la.
# Já a coluna da matricula (“matricula_ou_siape”) não está com um formato muito legível. Transforme-a em formato String.

# %%
# excluindo a coluna "registro_sistema"
dados_biblioteca_completos = dados_biblioteca_completos.drop('registro_sistema', axis=1)
dados_biblioteca_completos.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'ano_emprestimo', 'mes_emprestimo', 'nome_cdu'],
#       dtype='object')

# %%
# transformar o registro_sistema
dados_biblioteca_completos['matricula_ou_siape'] = dados_biblioteca_completos['matricula_ou_siape'].astype(str)
dados_biblioteca_completos.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'ano_emprestimo', 'mes_emprestimo', 'nome_cdu'],
#       dtype='object')

# %%
#verificando a tabela matricula_ou_siape
dados_biblioteca_completos.head(5)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#           data_emprestimo                 data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721  2010/01/05 16:26:12.662000000       2008023265.0
# 1 2010-03-01 12:40:56.212  2010/04/30 14:42:35.366000000       2009121584.0
# 2 2010-01-04 07:44:10.750  2010/01/12 07:34:13.934000000       2008023265.0
# 3 2010-02-11 11:16:30.335  2010/03/04 08:54:32.262000000       2008050352.0
# 4 2010-03-04 13:36:26.599  2010/03/31 18:04:29.669000000        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %% [markdown]
# # Dia 3 - Análise exploratória de dados e DateTime
# ## #7DaysOfCode - Python Pandas 3/7: Análise exploratória de dados e DateTime

# %%
# importar as bibliotecas de plotagem de graficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.dates as mdates

# %%
# verificando os emprestimos unicos
dados_biblioteca_completos['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 2010326     3
# 2014596     3
# 10240112    3
# 2422542     3
# 9690168     3
#            ..
# 2767562     1
# 2317930     1
# 2283256     1
# 2262867     1
# 2989061     1
# Name: count, Length: 2068724, dtype: int64

# %%
dados_biblioteca_completos.loc[dados_biblioteca_completos['id_emprestimo'] == 9690168]
# Out:
#          id_emprestimo codigo_barras data_renovacao         data_emprestimo  \
# 1942842        9690168    2016015319            NaN 2017-04-20 21:07:44.036
# 1942843        9690168    2016015319            NaN 2017-04-20 21:07:44.036
# 1942844        9690168    2016015319            NaN 2017-04-20 21:07:44.036
#
#                         data_devolucao matricula_ou_siape  \
# 1942842  2017/05/02 08:22:54.000000000       2015041228.0
# 1942843  2017/05/02 08:22:54.000000000       2015041228.0
# 1942844  2017/05/02 08:22:54.000000000       2015041228.0
#
#         tipo_vinculo_usuario  id_exemplar            colecao  \
# 1942842   ALUNO DE GRADUAÇÃO      1237700  Acervo Circulante
# 1942843   ALUNO DE GRADUAÇÃO      1239476  Acervo Circulante
# 1942844   ALUNO DE GRADUAÇÃO      1239477  Acervo Circulante
#
#                              biblioteca status_material  localizacao  \
# 1942842  Biblioteca Central Zila Mamede        ESPECIAL           32
# ...

# %% [markdown]
# ### remover duplicidade dos dados de id_emprestimo

# %%
emprestimos_biblioteca = dados_biblioteca_completos.drop_duplicates(subset='id_emprestimo')
emprestimos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                 data_emprestimo                 data_devolucao  \
# 0       2010-01-04 07:44:10.721  2010/01/05 16:26:12.662000000
# ...

# %%
dados_biblioteca_completos['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 2010326     3
# 2014596     3
# 10240112    3
# 2422542     3
# 9690168     3
#            ..
# 2767562     1
# 2317930     1
# 2283256     1
# 2262867     1
# 2989061     1
# Name: count, Length: 2068724, dtype: int64

# %%
dados_biblioteca_completos.loc[dados_biblioteca_completos['id_emprestimo'] == 2010326]
# Out:
#          id_emprestimo codigo_barras data_renovacao         data_emprestimo  \
# 1594544        2010326    2010082015            NaN 2015-06-02 17:56:18.917
# 1594545        2010326    2010082015            NaN 2015-06-02 17:56:18.917
# 1594546        2010326    2010082015            NaN 2015-06-02 17:56:18.917
#
#                         data_devolucao matricula_ou_siape  \
# 1594544  2015/06/19 15:42:51.000000000       2010023153.0
# 1594545  2015/06/19 15:42:51.000000000       2010023153.0
# 1594546  2015/06/19 15:42:51.000000000       2010023153.0
#
#         tipo_vinculo_usuario  id_exemplar            colecao  \
# 1594544   ALUNO DE GRADUAÇÃO      1055921  Acervo Circulante
# 1594545   ALUNO DE GRADUAÇÃO      1055569  Acervo Circulante
# 1594546   ALUNO DE GRADUAÇÃO      1056359  Acervo Circulante
#
#                              biblioteca status_material  localizacao  \
# 1594544  Biblioteca Central Zila Mamede         REGULAR          671
# ...

# %% [markdown]
# ### Quantos empréstimos foram realizados ao total?

# %%
emprestimos = dados_biblioteca_completos['id_emprestimo'].count()
emprestimos
# Out:
# 2072522

# %%
exemplares = dados_biblioteca_completos['id_exemplar'].count()
exemplares
# Out:
# 2072522

# %%
dados_biblioteca_completos.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'ano_emprestimo', 'mes_emprestimo', 'nome_cdu'],
#       dtype='object')

# %% [markdown]
# ### Quantos exempalres foram emprestados por ano?

# %%
emprestimos_por_ano = dados_biblioteca_completos.groupby('ano_emprestimo')['id_exemplar'].count()
emprestimos_por_ano
# Out:
# ano_emprestimo
# 2010    161394
# 2011    196390
# 2012    221365
# 2013    234749
# 2014    219189
# 2015    213582
# 2016    215900
# 2017    218462
# 2018    194080
# 2019    171801
# 2020     25610
# Name: id_exemplar, dtype: int64

# %% [markdown]
# Quantos exempalres foram emprestados por mes?

# %%
emprestimos_por_mes = dados_biblioteca_completos.groupby('mes_emprestimo')['id_exemplar'].count()
emprestimos_por_mes
# Out:
# mes_emprestimo
# 1      67514
# 2     210200
# 3     252185
# 4     208725
# 5     202530
# 6     138123
# 7     123790
# 8     232793
# 9     208234
# 10    188410
# 11    164222
# 12     75796
# Name: id_exemplar, dtype: int64

# %% [markdown]
# ### Modificar os números dos meses por nomes

# %%
def mes_para_nome(mes):
  if mes == 1:
    return 'Jan'
  elif mes == 2:
    return 'Fev'
  elif mes == 3:
    return 'Mar'
  elif mes == 4:
    return 'Abr'
  elif mes == 5:
    return 'Mai'
  elif mes == 6:
    return 'Jun'
  elif mes == 7:
    return 'Jul'
  elif mes == 8:
    return 'Ago'
  elif mes == 9:
    return 'Set'
  elif mes == 10:
    return 'Out'
  elif mes == 11:
    return 'Nov'
  elif mes == 12:
    return 'Dez'

# %%
# criar uma nova coluna cdu

dados_biblioteca_completos['mes'] = dados_biblioteca_completos['mes_emprestimo'].apply(mes_para_nome)

# %%
# verificar
emprestimos_por_mes = dados_biblioteca_completos.groupby('mes')['id_exemplar'].count()
emprestimos_por_mes
# Out:
# mes
# Abr    208725
# Ago    232793
# Dez     75796
# Fev    210200
# Jan     67514
# Jul    123790
# Jun    138123
# Mai    202530
# Mar    252185
# Nov    164222
# Out    188410
# Set    208234
# Name: id_exemplar, dtype: int64

# %% [markdown]
# ## Qual é a quantidade de emprestimo por hora?
# realizar o tratamento da hora tb

# %%
dados_biblioteca_completos.data_devolucao
# Out:
# 0          2010/01/05 16:26:12.662000000
# 1          2010/04/30 14:42:35.366000000
# 2          2010/01/12 07:34:13.934000000
# 3          2010/03/04 08:54:32.262000000
# 4          2010/03/31 18:04:29.669000000
#                        ...
# 2072517    2020/12/03 08:12:20.000000000
# 2072518    2021/01/07 11:16:28.000000000
# 2072519    2021/08/30 13:29:44.000000000
# 2072520                              NaN
# 2072521    2021/07/26 15:05:20.000000000
# Name: data_devolucao, Length: 2072522, dtype: object

# %%
#Extrair o ano da coluna 'data_emprestimo'
dados_biblioteca_completos['hora_emprestimo'] = dados_biblioteca_completos['data_emprestimo'].dt.hour

# %%
# Exibir o dataFrame com as novas colunas de mes e ano
print(dados_biblioteca_completos[['data_emprestimo', 'hora_emprestimo']])
# Out:
#                 data_emprestimo  hora_emprestimo
# 0       2010-01-04 07:44:10.721                7
# 1       2010-03-01 12:40:56.212               12
# 2       2010-01-04 07:44:10.750                7
# 3       2010-02-11 11:16:30.335               11
# 4       2010-03-04 13:36:26.599               13
# ...                         ...              ...
# 2072517 2020-03-17 19:49:10.187               19
# 2072518 2020-03-17 19:51:15.700               19
# 2072519 2020-03-17 20:00:11.416               20
# 2072520 2020-03-17 20:47:18.741               20
# 2072521 2020-03-17 21:22:22.138               21
#
# [2072522 rows x 2 columns]

# %%
# Agora verificar quantos emprestimo é realizado por hora
emprestimos_por_hora = dados_biblioteca_completos.groupby('hora_emprestimo')['id_emprestimo'].count()
emprestimos_por_hora
# Out:
# hora_emprestimo
# 0         17
# 6         14
# 7      18777
# 8     103416
# 9     131273
# 10    185839
# 11    180048
# 12    148754
# 13    126987
# 14    150876
# 15    166672
# 16    210655
# 17    185340
# 18    182520
# 19    102129
# 20    127716
# 21     51191
# 22       247
# 23        51
# Name: id_emprestimo, dtype: int64

# %% [markdown]
# ## plotando os graficos

# %% [markdown]
# ###  Utilizando matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Grafico de linha

# %%
# plotar o grafico de emprestimo e ano
dados_biblioteca_completos.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'ano_emprestimo', 'mes_emprestimo', 'nome_cdu', 'mes',
#        'hora_emprestimo'],
#       dtype='object')

# %%
#agrupar por ano e soamr as quantidades por ano
emprestimos_por_ano = dados_biblioteca_completos.groupby('ano_emprestimo')['id_emprestimo'].sum()
emprestimos_por_ano
# Out:
# ano_emprestimo
# 2010     129210500640
# 2011     203578740351
# 2012     282235296027
# 2013     359176481568
# 2014     389569612595
# 2015     428828709091
# 2016     508843924469
# 2017    2154756012244
# 2018     520446716322
# 2019     493524118908
# 2020      76209699106
# Name: id_emprestimo, dtype: int64

# %%
# plotar os dados
plt.plot(emprestimos_por_ano.index, emprestimos_por_ano.values)
plt.xlabel('Ano')
plt.ylabel('Quantidade de empréstimos')
plt.title('Quantidade de empréstimos ao longo dos anos')
plt.show()

# %%
#agrupar por ano e soamr as quantidades por mes
emprestimos_por_mes = dados_biblioteca_completos.groupby('mes')['id_emprestimo'].sum()
emprestimos_por_mes
# Out:
# mes
# Abr    534473933874
# Ago    652743250379
# Dez    181679237751
# Fev    544232680143
# Jan    160188175738
# Jul    355197314857
# Jun    390903709001
# Mai    546718094029
# Mar    677853346103
# Nov    438442853349
# Out    508727956575
# Set    555219259522
# Name: id_emprestimo, dtype: int64

# %%
# plotar os dados
plt.plot(emprestimos_por_mes.index, emprestimos_por_mes.values)
plt.xlabel('Mês')
plt.ylabel('Quantidade de empréstimos')
plt.title('Quantidade de empréstimos ao longo dos Mês')
plt.show()

# %%
#agrupar por ano e soamr as quantidades por hora
emprestimos_por_hora = dados_biblioteca_completos.groupby('hora_emprestimo')['id_emprestimo'].sum()
emprestimos_por_hora
# Out:
# hora_emprestimo
# 0         28140189
# 6         31478526
# 7      53098298394
# 8     270476175091
# 9     343154676843
# 10    492484199952
# 11    477938579480
# 12    400267165045
# 13    343313918161
# 14    410683819212
# 15    449858745988
# 16    570771528523
# 17    496894919224
# 18    488057103202
# 19    275429603789
# 20    333117176255
# 21    140069791596
# 22       609121333
# 23        95370518
# Name: id_emprestimo, dtype: int64

# %%
# plotar os dados
plt.plot(emprestimos_por_hora.index, emprestimos_por_hora.values)
plt.xlabel('Hora')
plt.ylabel('Quantidade de empréstimos')
plt.title('Quantidade de empréstimos ao longo dos Hora')
plt.show()

# %% [markdown]
# ## Gráfico de barras

# %%
# plotar os dados
plt.bar(emprestimos_por_hora.index, emprestimos_por_hora.values)
plt.xlabel('Hora')
plt.ylabel('Quantidade de empréstimos')
plt.title('Quantidade de empréstimos ao longo das Hora')
plt.show()

# %%
# plotar os dados de emprestimo ao longo do Ano
plt.bar(emprestimos_por_ano.index, emprestimos_por_ano.values)
plt.xlabel('Ano')
plt.ylabel('Quantidade de empréstimos')
plt.title('Quantidade de empréstimos ao longo dos Ano')
plt.show()

# %%
# plotar os dados
plt.bar(emprestimos_por_mes.index, emprestimos_por_mes.values)
plt.xlabel('Mes')
plt.ylabel('Quantidade de empréstimos')
plt.title('Quantidade de empréstimos ao longo dos mes')
plt.show()

# %% [markdown]
# ## Dia 4 - 👩🏽‍💻 Análise exploratória de dados e Variáveis categóricas

# %% [markdown]
# Hoje você vai continuar a questionar ainda mais os seus dados para extrair ainda mais informações deles.
#
# O objetivo será entender a quantidade de empréstimos a partir das variáveis categóricas do seu conjunto de dados.
# Bom, um conjunto de dados é descrito pelas suas características que variam de acordo com cada um, por exemplo: peso, idade, quantidade de páginas, notas, nome da biblioteca, número de empréstimos, número de filhos, etc.
#
# Elas podem ser classificadas em dois grandes grupos que se subdividem em mais dois outros grupos cada.
#
# **Quantitativas:** são características numéricas que podemos enumerar:
#
#
# - Discreta: possuem apenas valores finitos enumeráveis. Exemplo: número de empréstimos, número de filhos, número de páginas.
#
# - Contínua: possuem valores dentro de um intervalo de números. Exemplo: altura, peso, notas.
#
# **Categóricas (ou qualitativas):** são características não-numéricas para as quais podemos definir categorias.
#
#
# - Nominal: possuem categorias não ordenadas naturalmente. Exemplo: nomes, cores, tema do livro.
#
# - Ordinal: são categorias onde está implícito um tipo de ordenamento ou hierarquia. Exemplo: classe social, nível de escolaridade.
#
# Vamos explorar algumas das variáveis categóricas das quais precisaremos extrair mais informações. Elas são:
#
#
# - Tipo de vínculo
# - Coleção
# - Biblioteca
# - Classificação geral da CDU
#
# Ao se analisar uma nova variável, é bem interessante verificar cada uma listando quais são os valores únicos dentro delas.
#
# Para explorar os dados, alguns questionamentos serão pertinentes para a diretoria das bibliotecas, como:
#
#
# - **“Como se distribuem os empréstimos de exemplares pelos tipos de vínculo dos usuários?”**
# Desta forma, a diretoria poderá entender qual é o público que está utilizando a biblioteca e assim tomar decisões em continuar com a estratégia de negócio atual ou modificá-la.
#
# - **Quais coleções são mais emprestadas?**
# Da mesma forma, as coleções. Ranquear as coleções mais emprestadas pelo público, será bastante importante para a estratégia atual.
#
# - **Quais são as bibliotecas com mais ou menos quantidade de empréstimos?**
# Assim, a diretoria conseguirá entender onde ela deverá melhorar e focar suas iniciativas.
#
# Você visualizará os dados dos empréstimos que aconteceram, mas e os dados que não estão aqui na análise?
#
# Por quais outras perspectivas você pode entender essa tabela de como ela se formou? Comparar bibliotecas de tamanhos diferentes, com públicos diferentes, acervos diferentes... isso faz sentido para a diretoria do sistema de bibliotecas?
#
# Aponte algumas outras métricas que poderiam entrar aqui para enriquecer essa análise.
#
#
# - De quais temas da CDU são os exemplares emprestados?
#
# Entender quais os temas mais procurados pelos usuários é fundamental para o desenvolvimento de novos planos de marketing do acervo. Para que possam não apenas fortalecer o que está sendo utilizado, mas também promover o que não está.
#
# Gere uma tabela de frequência e com o percentual para cada variável.
#
# Como é um trabalho repetitivo, crie uma função que gere a tabela com os valores.
#
# Após geradas as tabelas, traga algumas das suas percepções para as análises com o que você poderá contribuir para a diretoria da biblioteca.

# %%
# Importanção das bibliotecas a ser utilizada neste dia
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %%
emprestimos_biblioteca.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'ano_emprestimo', 'mes_emprestimo', 'nome_cdu'],
#       dtype='object')

# %%
emprestimos_biblioteca.head(5)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         726965       L095049  2010/03/31 12:41:08.684000000
# 2         709685       L167050                            NaN
# 3         717763       L167050                            NaN
# 4         729996       L167050  2010/03/17 09:08:26.874000000
#
#           data_emprestimo                 data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721  2010/01/05 16:26:12.662000000       2008023265.0
# 1 2010-03-01 12:40:56.212  2010/04/30 14:42:35.366000000       2009121584.0
# 2 2010-01-04 07:44:10.750  2010/01/12 07:34:13.934000000       2008023265.0
# 3 2010-02-11 11:16:30.335  2010/03/04 08:54:32.262000000       2008050352.0
# 4 2010-03-04 13:36:26.599  2010/03/31 18:04:29.669000000        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
emprestimos_biblioteca.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'ano_emprestimo', 'mes_emprestimo', 'nome_cdu'],
#       dtype='object')

# %% [markdown]
# ### Verificar valores únicos das colunas ou variáveis

# %%
# variavel tipo_vinculo_usuario
emprestimos_biblioteca['tipo_vinculo_usuario'].unique()
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'ALUNO DE PÓS-GRADUAÇÃO', 'DOCENTE',
#        'DOCENTE EXTERNO', 'SERVIDOR TÉCNICO-ADMINISTRATIVO',
#        'ALUNO MÉDIO/TÉCNICO', 'USUÁRIO EXTERNO', 'OUTROS'], dtype=object)

# %%
emprestimos_biblioteca['tipo_vinculo_usuario'].value_counts()
# Out:
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                 1609591
# ALUNO DE PÓS-GRADUAÇÃO              301902
# DOCENTE                              70865
# SERVIDOR TÉCNICO-ADMINISTRATIVO      32128
# ALUNO MÉDIO/TÉCNICO                  27917
# DOCENTE EXTERNO                      23808
# USUÁRIO EXTERNO                       2508
# OUTROS                                   5
# Name: count, dtype: int64

# %%
# colecao
emprestimos_biblioteca['colecao'].unique()
# Out:
# array(['Acervo Circulante', 'Folhetos', 'Teses', 'Dissertações',
#        'Monografias', 'Publicações de Autores do RN',
#        'Publicações da UFRN', 'Multimeios', 'Coleção Mossoroense',
#        'Eventos', 'Trabalho Acadêmico', 'Obras de Referência',
#        'Obras Raras', 'Literatura de Cordel', 'Coleção Zila Mamede',
#        'Necessidades Educacionais Específicas'], dtype=object)

# %%
emprestimos_biblioteca['colecao'].value_counts()
# Out:
# colecao
# Acervo Circulante                        2049408
# Multimeios                                  7929
# Monografias                                 4021
# Dissertações                                2404
# Obras de Referência                         1904
# Publicações de Autores do RN                 857
# Publicações da UFRN                          764
# Teses                                        714
# Folhetos                                     271
# Necessidades Educacionais Específicas        130
# Trabalho Acadêmico                           115
# Eventos                                      101
# Coleção Mossoroense                           44
# Coleção Zila Mamede                           30
# Literatura de Cordel                          24
# Obras Raras                                    8
# Name: count, dtype: int64

# %%
# status_material
emprestimos_biblioteca['status_material'].unique()
# Out:
# array(['REGULAR', 'ESPECIAL', 'NÃO CIRCULA'], dtype=object)

# %%
emprestimos_biblioteca['status_material'].value_counts()
# Out:
# status_material
# REGULAR        1997135
# ESPECIAL         69563
# NÃO CIRCULA       2026
# Name: count, dtype: int64

# %%
# nome_cdu
emprestimos_biblioteca['nome_cdu'].unique()
# Out:
# array(['Ciências aplicadas.', 'Linguagem. Língua. Linguística.',
#        'Ciências sociais', 'Geografia. Biografia. História.',
#        'Matemática e ciências naturais.', 'Religião',
#        'Generalidades. Ciência e conhecimento.',
#        'Filosofia e psicologia.', 'Belas artes.'], dtype=object)

# %%
emprestimos_biblioteca['nome_cdu'].value_counts()
#
# Out:
# nome_cdu
# Ciências aplicadas.                       1423585
# Ciências sociais                           368692
# Matemática e ciências naturais.             68409
# Generalidades. Ciência e conhecimento.      62284
# Religião                                    62169
# Filosofia e psicologia.                     60308
# Geografia. Biografia. História.              7943
# Belas artes.                                 7870
# Linguagem. Língua. Linguística.              7464
# Name: count, dtype: int64

# %%
# biblioteca
emprestimos_biblioteca['biblioteca'].unique()
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
# ...

# %%
emprestimos_biblioteca['biblioteca'].value_counts()
# Out:
# biblioteca
# Biblioteca Central Zila Mamede                                                              1423413
# Biblioteca Setorial do Centro Ciências da Saúde - CCS                                        118590
# Biblioteca Setorial da Faculdade de Ciências da Saúde do Trairi - FACISA - Santa Cruz         77584
# Biblioteca Setorial Prof. Alberto Moreira Campos - ­Departamento de Odontologia               66441
# Biblioteca Setorial Profª. Maria Lúcia da Costa Bezerra - ­CERES­ - Caicó                     61344
# Biblioteca Setorial Bertha Cruz Enders - ­Escola de Saúde da UFRN - ESUFRN                    46017
# Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA                     40728
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN - Caicó                                       32096
# Biblioteca Setorial Profª. Maria José Mamede Galvão - FELCS - Currais Novos                   29032
# ...

# %% [markdown]
# ## Função
# ### Criar uma função que conta a quantidade e o percentual da variavel
#
# Gere uma tabela de frequência e com o percentual para cada variável.
#
# Após geradas as tabelas, traga algumas das suas percepções para as análises com o que você poderá contribuir para a diretoria da biblioteca.

# %%
def tabela_frequencia(variavel):
  dataSet = pd.DataFrame(emprestimos_biblioteca[variavel].value_counts())
  dataSet.columns = ['Quantidade']
  dataSet['Percentual'] = (dataSet['Quantidade'] / dataSet['Quantidade'].sum()) * 100
  dataSet['Percentual'] = dataSet['Percentual'].map('{:.2f}%'.format)
  return dataSet

# %% [markdown]
# ## Quantos emprestimos por tipo de vinculos do usuarios?
# Quantidades e Porcentagem

# %%
tabela_frequencia('tipo_vinculo_usuario')
# Out:
#                                  Quantidade Percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1609591     77.81%
# ALUNO DE PÓS-GRADUAÇÃO               301902     14.59%
# DOCENTE                               70865      3.43%
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32128      1.55%
# ALUNO MÉDIO/TÉCNICO                   27917      1.35%
# DOCENTE EXTERNO                       23808      1.15%
# USUÁRIO EXTERNO                        2508      0.12%
# OUTROS                                    5      0.00%

# %% [markdown]
# O maior publico é de alunos De graduação com 77.81% segundo os de pos graduação
# Sendo que a maior numero de alunos na graduação

# %% [markdown]
# ## Quantos por coleção

# %%
tabela_frequencia('colecao')
# Out:
#                                        Quantidade Percentual
# colecao
# Acervo Circulante                         2049408     99.07%
# Multimeios                                   7929      0.38%
# Monografias                                  4021      0.19%
# Dissertações                                 2404      0.12%
# Obras de Referência                          1904      0.09%
# Publicações de Autores do RN                  857      0.04%
# Publicações da UFRN                           764      0.04%
# Teses                                         714      0.03%
# Folhetos                                      271      0.01%
# Necessidades Educacionais Específicas         130      0.01%
# Trabalho Acadêmico                            115      0.01%
# Eventos                                       101      0.00%
# Coleção Mossoroense                            44      0.00%
# Coleção Zila Mamede                            30      0.00%
# ...

# %% [markdown]
# o numero de averso circulante é de 99 % dos emprestimos isto se justifica pelo fato de algums acervos não poder ser emprestados

# %% [markdown]
# ## Qual é o status dos emprestimos?

# %%
tabela_frequencia('status_material')
# Out:
#                  Quantidade Percentual
# status_material
# REGULAR             1997135     96.54%
# ESPECIAL              69563      3.36%
# NÃO CIRCULA            2026      0.10%

# %% [markdown]
# 96 % dos emprestimos está em situação regular

# %% [markdown]
# ## Quantos por biblioteca?

# %%
tabela_frequencia('biblioteca')
# Out:
#                                                     Quantidade Percentual
# biblioteca
# Biblioteca Central Zila Mamede                         1423413     68.81%
# Biblioteca Setorial do Centro Ciências da Saúde...      118590      5.73%
# Biblioteca Setorial da Faculdade de Ciências da...       77584      3.75%
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66441      3.21%
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61344      2.97%
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46017      2.22%
# Biblioteca Setorial do Centro de Ciências Human...       40728      1.97%
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32096      1.55%
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29032      1.40%
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       26994      1.30%
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26669      1.29%
# ...

# %% [markdown]
# A biblioteca central corresponde a 68 % dos empretimos o que pode se dizer que era o esperado

# %% [markdown]
# ## Quantos foram pela CDU pelo seus nomes?

# %%
tabela_frequencia('nome_cdu')
# Out:
#                                         Quantidade Percentual
# nome_cdu
# Ciências aplicadas.                        1423585     68.81%
# Ciências sociais                            368692     17.82%
# Matemática e ciências naturais.              68409      3.31%
# Generalidades. Ciência e conhecimento.       62284      3.01%
# Religião                                     62169      3.01%
# Filosofia e psicologia.                      60308      2.92%
# Geografia. Biografia. História.               7943      0.38%
# Belas artes.                                  7870      0.38%
# Linguagem. Língua. Linguística.               7464      0.36%

# %% [markdown]
# ## Grafico dos valores calculados acima

# %% [markdown]
# ### tipo de vinculo do usuario

# %%
# importando as bibliotecs
import numpy as np
import matplotlib.pyplot as plt

# %%
# grafico de barra tipo de usuario
plt.figure(figsize=(20, 6))
plt.bar(tabela_frequencia('tipo_vinculo_usuario').index, tabela_frequencia('tipo_vinculo_usuario')['Quantidade'], color='orange')
plt.xlabel('Tipo de Vínculo')
plt.ylabel('Quantidade')
plt.title('Quantidade de Empréstimos por Tipo de Vínculo')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
tipo_vinculo_usuario = tabela_frequencia('tipo_vinculo_usuario')
tipo_vinculo_usuario
# Out:
#                                  Quantidade Percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1609591     77.81%
# ALUNO DE PÓS-GRADUAÇÃO               301902     14.59%
# DOCENTE                               70865      3.43%
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32128      1.55%
# ALUNO MÉDIO/TÉCNICO                   27917      1.35%
# DOCENTE EXTERNO                       23808      1.15%
# USUÁRIO EXTERNO                        2508      0.12%
# OUTROS                                    5      0.00%

# %%
# grafico percentual
# semelhante ao bar( ) temos o barh()
plt.figure(figsize=(20, 6))
plt.barh(tabela_frequencia('tipo_vinculo_usuario').index, tabela_frequencia('tipo_vinculo_usuario')['Quantidade'], color='orange')
plt.xlabel('Qauntidades')
plt.ylabel('Tipo de Vínculo')
plt.title('Percentual de Empréstimos por Tipo de Vínculo')
plt.show()

# %% [markdown]
# # Dia 5 - Análise exploratória de dados e Boxplot
# ## #7DaysOfCode - Python Pandas 5/7: Análise exploratória de dados e Boxplot
# Hoje vamos bater um papo sobre Boxplot. O Boxplot é uma das visualizações mais poderosas que existe, pois ele permite que você visualize medidas estatísticas como a mediana, os quartis, os valores mínimos e máximos e os valores atípicos outliers.¹
# Este gráfico foi criado pelo matemático John Tukey na década de 70 no seu livro “Exploratory Data Analysis”.
#
# Sim, foi ele quem promoveu a análise exploratória de dados.
#
# O gráfico possui uma estrutura formada por uma caixa retangular, uma linha cortando essa caixa e as hastes (ou bigodes) ligadas a caixa.
#
# 15db40af-1f4b-4ea8-be19-bacabb098ed2
# Os quartis são representados pelos limites da caixa, do quartil inferior (Q1) ao quartil superior (Q3). A mediana (é o Q2) é representada pela linha. Os valores mínimos e máximos são as extremidades das hastes e os outliers são todos os pontos além destes limites.
#
# Hoje, você irá praticar algumas visualizações para entender melhor os dados e desenvolver uma análise em cima do problema.
#
# Bora lá?!
#
# Desenvolver estratégias para o uso da informação é uma tarefa constante, devido às diversas mudanças que ocorrem o tempo todo: os usuários estão evoluindo seus conhecimentos, novos alunos chegam, alunos que se formam saem e as informações estão sempre em movimento e transformação.
#
# Por este motivo, é importante realizar avaliações constantes do uso da biblioteca e entender em quais cenários (tipos de usuários, estratégias de marketing, atualização de acervo, cenário sócio-político interno e externo) é melhor manter a estratégia atual ou mudá-la.
#
# Você vai fazer dois recortes em seus dados para entender como eles se distribuíram ao decorrer desses anos e, desta forma, possa trazer inferências para levar à diretoria da biblioteca, a fim de que eles possam tomar decisões para o ano atual.
#
# Para isso, você vai avaliar dentre os alunos de graduação e pós graduação a distribuição de empréstimos mensais por ano realizados entre 2010 e 2020 da coleção que tiver a maior frequência de empréstimos.
#
# Plote um gráfico para cada tipo de usuário.
# Tenha um boxplots para cada ano e analise o que ocorreu.
#
# O que está ocorrendo ao decorrer do tempo? Houve algum ano ou anos em específico que te chamaram atenção para alguma diferença? Quais as maiores diferenças entre os empréstimos para os alunos de graduação e pós graduação?
#
# ## Dicas
#
# Desenvolva a tarefa uma etapa por vez:
#
# - Verifique qual é a coleção com maior frequência para cada tipo de usuário.
# - Filtre os dados com condições solicitadas
# - Selecione apenas os empréstimos
# - Faça a contagem de empréstimos mensais por cada ano
# - Crie uma função para gerar a visualização do gráfico de box plot por cada ano.
# - Crie o gráfico de boxplot
#
# ## Extra
#
# Fique livre para escolher a biblioteca que desejar para plotar o gráfico, mas não deixe de conferir a documentação:
#
# - [Matplotlib](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html)
# - [Pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.boxplot.html?utm_medium=email&_hsenc=p2ANqtz-9XMAdlvG33Wnru67q-p1927ucOpU5OZbbFniQaOmBkZAYBCFJ0YXgyIImM_0poRT3P8ADP27qjfW9-RRDz9Lvk5ttL-Q&_hsmi=270879687&utm_content=270879687&utm_source=hs_automation)
# - [Seaborn](https://seaborn.pydata.org/generated/seaborn.boxplot.html?utm_medium=email&_hsenc=p2ANqtz--RnuwOu8TPfKwhwkZOmEWW4KcldBFJFTyjjKkgSCxxLokCL34gAHWVErvY0W98Z5H6evMhQaAe3K4CQiV7L4YEcfOz6Q&_hsmi=270879687&utm_content=270879687&utm_source=hs_automation)
# - [Plotly](https://plotly.com/python/box-plots/?utm_medium=email&_hsenc=p2ANqtz-_E5SqD9H5Ac7BOvr27EFMLcZqdHWjIvtVnGl0i3SE9xk-34PVSCEKHEpclOAKikDuUS8Of-E9L44QFjElLmHSyittIGA&_hsmi=270879687&utm_content=270879687&utm_source=hs_automation)
#
# Para o Seaborn, verifique também sobre a [paleta de cores](https://seaborn.pydata.org/tutorial/color_palettes.html?utm_medium=email&_hsenc=p2ANqtz-9do52uuoVck3HapetFDxoF0sqTWJ8R6j2oHS5XmrUPhzYSPJnJ33VKgEC3QAwzGD6hHhpHH5VYFvcHtWgU-WEz1n1dCQ&_hsmi=270879687&utm_content=270879687&utm_source=hs_automation) e as [configurações estéticas](https://seaborn.pydata.org/tutorial/aesthetics.html?utm_medium=email&_hsenc=p2ANqtz-8hv3-p0sFiX7WathY00R2vssyWHL32Sb77dLmEaS0N_Jm23LiSAryd3vuxUKqVewsBGPC1Uk6mI6M8sR0ZsFDkUmWPNA&_hsmi=270879687&utm_content=270879687&utm_source=hs_automation) gerais dos gráficos.
#
# Quer criar gráficos dinâmicos? Confira esse [meu texto](https://franciscofoz.medium.com/como-criar-um-boxplot-com-python-no-plotly-252a77fdecf4) de como criar um boxplot com o Plotly.
#
# Capriche e se atente para desenvolver um gráfico limpo e objetivo.
#
# Caso se interesse em saber mais sobre o boxplot, confira esse artigo científico especificamente sobre o gráfico no qual é a referência anotada.

# %% [markdown]
# ### Verifique qual é a coleção com maior frequência para cada tipo de usuário.
# utilizando as ferramentas de estatistica boxplot

# %%
# importando as bibliotecas que seram utilizadas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# - Correlaçoes das tabelas

# %%
# tabela_cruzada = pd.crosstab(dados['COR/RACA/ETNIA'],dados['NIVEL DE ENSINO'])
tipo_colecao = pd.crosstab(emprestimos_biblioteca['tipo_vinculo_usuario'],emprestimos_biblioteca['colecao'])
tipo_colecao
# Out:
# colecao                          Acervo Circulante  Coleção Mossoroense  \
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                         1597478                   17
# ALUNO DE PÓS-GRADUAÇÃO                      298583                   23
# ALUNO MÉDIO/TÉCNICO                          25902                    0
# DOCENTE                                      69583                    4
# DOCENTE EXTERNO                              23724                    0
# OUTROS                                           5                    0
# SERVIDOR TÉCNICO-ADMINISTRATIVO              31628                    0
# USUÁRIO EXTERNO                               2505                    0
#
# colecao                          Coleção Zila Mamede  Dissertações  Eventos  \
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                                15          1150       57
# ALUNO DE PÓS-GRADUAÇÃO                            11           934       26
# ...

# %%
#tabela com todos os alunos de graduação e as coleção
emprestimos_biblioteca_graduacao = emprestimos_biblioteca[(emprestimos_biblioteca['tipo_vinculo_usuario'] == 'ALUNO DE GRADUAÇÃO') & (emprestimos_biblioteca['colecao'])].value_counts()
emprestimos_biblioteca_graduacao
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo          data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario  id_exemplar  colecao            biblioteca                                               status_material  localizacao  ano_emprestimo  mes_emprestimo  nome_cdu
# 709687         L184117        2010/01/18 11:07:46.470000000  2010-01-04 08:24:21.284  2010/02/03 08:58:45.692000000  200721119.0         ALUNO DE GRADUAÇÃO    131639       Acervo Circulante  Biblioteca Central Zila Mamede                           REGULAR          609          2010            1               Ciências aplicadas.    1
# 2330242        2010089499     2016/11/28 07:34:43.359000000  2016-10-31 14:51:13.505  2016/12/07 14:29:57.000000000  2016030318.0        ALUNO DE GRADUAÇÃO    897535       Acervo Circulante  Biblioteca Central Zila Mamede                           REGULAR          636          2016            10              Ciências aplicadas.    1
# ...

# %%
emprestimos_biblioteca['colecao'].unique()
# Out:
# array(['Acervo Circulante', 'Folhetos', 'Teses', 'Dissertações',
#        'Monografias', 'Publicações de Autores do RN',
#        'Publicações da UFRN', 'Multimeios', 'Coleção Mossoroense',
#        'Eventos', 'Trabalho Acadêmico', 'Obras de Referência',
#        'Obras Raras', 'Literatura de Cordel', 'Coleção Zila Mamede',
#        'Necessidades Educacionais Específicas'], dtype=object)

# %%
alunos_graduacao = emprestimos_biblioteca[emprestimos_biblioteca['tipo_vinculo_usuario'] == 'ALUNO DE GRADUAÇÃO']
alunos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        1597478
# Multimeios                                  4632
# Monografias                                 3572
# Dissertações                                1150
# Obras de Referência                         1015
# Publicações de Autores do RN                 593
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: count, dtype: int64

# %%
alunos_graduacao = emprestimos_biblioteca[
    (emprestimos_biblioteca['tipo_vinculo_usuario'] == 'ALUNO DE GRADUAÇÃO') &
    (emprestimos_biblioteca['colecao'] == 'Acervo Circulante')
]

# Contagem dos valores por ano de empréstimo
quantidade_por_ano = alunos_graduacao.groupby('ano_emprestimo')['id_emprestimo'].count()

# %%
alunos_graduacao
# Out:
#      Ano  Quantidade
# 0   2013      185592
# 1   2012      177157
# 2   2014      169890
# 3   2017      165284
# 4   2016      163483
# 5   2015      162492
# 6   2011      157747
# 7   2018      145250
# 8   2019      127256
# 9   2010      124770
# 10  2020       18557

# %%
plt.figure(figsize=(20, 6))
sns.boxplot(data=alunos_graduacao, x='Ano', y='Quantidade')
plt.xlabel('Ano de Empréstimo')
plt.ylabel('Quantidade de Empréstimos')
plt.title('Distribuição de Empréstimos por Ano')
plt.show()

# %%
alunos_graduacao.describe()
# Out:
#                Ano     Quantidade
# count    11.000000      11.000000
# mean   2015.000000  145225.272727
# std       3.316625   46080.638223
# min    2010.000000   18557.000000
# 25%    2012.500000  136253.000000
# 50%    2015.000000  162492.000000
# 75%    2017.500000  167587.000000
# max    2020.000000  185592.000000

# %%
# não compriendi bem os graficos de boxplot estudar mais

# %% [markdown]
# ## solução do professor
# sobre os graficos

# %%
emprestimos_biblioteca.columns
# Out:
# Index(['id_emprestimo', 'codigo_barras', 'data_renovacao', 'data_emprestimo',
#        'data_devolucao', 'matricula_ou_siape', 'tipo_vinculo_usuario',
#        'id_exemplar', 'colecao', 'biblioteca', 'status_material',
#        'localizacao', 'ano_emprestimo', 'mes_emprestimo', 'nome_cdu'],
#       dtype='object')

# %%
# alunos de graduação
alunos_graduacao = emprestimos_biblioteca.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
alunos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        1597478
# Multimeios                                  4632
# Monografias                                 3572
# Dissertações                                1150
# Obras de Referência                         1015
# Publicações de Autores do RN                 593
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: count, dtype: int64

# %%
# Criando tabela com a quantidade mensal por ano
alunos_graduacao_acervo_circulante = alunos_graduacao.query('colecao == "Acervo Circulante"')
alunos_graduacao_acervo_circulante = pd.DataFrame(alunos_graduacao_acervo_circulante)
alunos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_graduacao_acervo_circulante['data_emprestimo'])
alunos_graduacao_acervo_circulante['ano'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_graduacao_acervo_circulante['mes'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.loc[:,['ano','mes']]
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_graduacao_acervo_circulante
#
# Out:
#       ano  mes  quantidade
# 0    2012    3       22776
# 1    2015    3       22434
# 2    2013    4       21833
# 3    2017    3       21698
# 4    2016    3       21655
# ..    ...  ...         ...
# 118  2016    1        2664
# 119  2019    1        2267
# 120  2019   12        1966
# 121  2020    1        1775
# 122  2011    1         809
#
# [123 rows x 3 columns]

# %%
# Função gera_box_plot
def gera_box_plot(dataset,x,y,titulo,subtitulo):
  '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  subtitulo = subtitulo do texto
  '''

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)
  plt.figure(figsize=(16,10))

  ax = sns.boxplot(y= y, x= x, data= dataset,color='#4171EF')
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))


  plt.ylim(0,max(dataset[y])*1.1)                                               #Definir o limite do eixo y
  plt.xlabel(None)
  plt.ylabel(None)

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %%
# Distribuição dos empréstimos mensais realizados pelos alunos de graduação na coleção do acervo circulante
gera_box_plot(alunos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos empréstimos por ano', 'Realizados pelos alunos de graduação no acervo circulante')

# %%
# Distribuição dos empréstimos mensais realizados pelos alunos de graduação na coleção do acervo circulante
gera_box_plot(alunos_graduacao_acervo_circulante,'mes','quantidade','Distribuição dos empréstimos mensal', 'Realizados pelos alunos de graduação no acervo circulante')
